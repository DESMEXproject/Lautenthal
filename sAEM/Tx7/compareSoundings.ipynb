# %%
import numpy as np
from saem import CSEMData

# %%
txpos = np.genfromtxt("Tx7.pos").T[:, ::-1]
# Nvec = [1, 2, 4, 8, 16, 32, 64]:
Nvec = [2, 4, 8, 32]
DATA = []
for i in Nvec:
    data = CSEMData(datafile=f"tfN{i}/*.mat", txPos=txpos) # 2 Cycle
    data.setOrigin([580000., 5740000.])
    data.filter(fmin=12, fmax=2000)
    DATA.append(data)
# Out:
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ['tfN2\\20220912_145823_L7011.mat', 'tfN2\\20220912_145823_L7019.mat', 'tfN2\\20220912_145823_L7021.mat', 'tfN2\\20220912_145823_L7029.mat', 'tfN2\\20220912_145823_L7031.1.mat', 'tfN2\\20220912_145823_L7031.mat', 'tfN2\\20220912_145823_L7039.mat', 'tfN2\\20220912_145823_L7041.1.mat', 'tfN2\\20220912_145823_L7041.mat', 'tfN2\\20220912_145823_L7049.mat', 'tfN2\\20220912_145823_L7051.1.mat', 'tfN2\\20220912_145823_L7051.mat', 'tfN2\\20220912_145823_L7061.mat', 'tfN2\\20220912_145823_L7069.mat', 'tfN2\\20220912_145823_L7071.mat', 'tfN2\\20220912_145823_L7081.mat', 'tfN2\\20220912_145823_L7091.mat', 'tfN2\\20220912_145823_L7101.mat', 'tfN2\\20220912_145823_L7111.mat', 'tfN2\\20220912_145823_L7121.mat', 'tfN2\\20220912_145823_L7131.mat', 'tfN2\\20220912_145823_L7141.mat', 'tfN2\\20220912_145823_L7151.mat']
# No frequency in data, try read WWU style
# read tfN2\20220912_145823_L7011.mat
# reading tfN2\20220912_145823_L7019.mat
# reading tfN2\20220912_145823_L7021.mat
# reading tfN2\20220912_145823_L7029.mat
# reading tfN2\20220912_145823_L7031.1.mat
# reading tfN2\20220912_145823_L7031.mat
# reading tfN2\20220912_145823_L7039.mat
# reading tfN2\20220912_145823_L7041.1.mat
# reading tfN2\20220912_145823_L7041.mat
# reading tfN2\20220912_145823_L7049.mat
# reading tfN2\20220912_145823_L7051.1.mat
# reading tfN2\20220912_145823_L7051.mat
# reading tfN2\20220912_145823_L7061.mat
# reading tfN2\20220912_145823_L7069.mat
# reading tfN2\20220912_145823_L7071.mat
# reading tfN2\20220912_145823_L7081.mat
# reading tfN2\20220912_145823_L7091.mat
# reading tfN2\20220912_145823_L7101.mat
# reading tfN2\20220912_145823_L7111.mat
# reading tfN2\20220912_145823_L7121.mat
# reading tfN2\20220912_145823_L7131.mat
# reading tfN2\20220912_145823_L7141.mat
# reading tfN2\20220912_145823_L7151.mat
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8324\3647365096.py in <cell line: 5>()
#       4 DATA = []
#       5 for i in Nvec:
# ----> 6     data = CSEMData(datafile=f"tfN{i}/*.mat", txPos=txpos) # 2 Cycle
#       7     data.setOrigin([580000., 5740000.])
#       8     data.filter(fmin=12, fmax=2000)
#
# ~\SAEM\saem\saem.py in __init__(self, datafile, **kwargs)
#      62
#      63         if datafile is not None:
# ---> 64             self.loadData(datafile)
#      65
#      66         self.chooseData()
#
# ~\SAEM\saem\saem.py in loadData(self, filename, detectLines)
#      86             if not self.loadEmteresMatFile(filename):
#      87                 print("No frequency in data, try read WWU style")
# ---> 88                 self.loadWWUMatFile(filename)
#      89
#      90         if len(self.line) != len(self.rx):
#
# ~\SAEM\saem\saem.py in loadWWUMatFile(self, filename)
#     218                     assert np.allclose(MAT[name], MAT1[name]), "freqs no match"
#     219                 else:
# --> 220                     MAT[name] = np.concatenate((MAT[name], MAT1[name]),
#     221                                                axis=-1)
#     222
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 4 dimension(s) and the array at index 1 has 3 dimension(s)

# %%
cmpx = [1, 0, 0]
cmpy = [0, 1, 0]
cmpz = [0, 0, 1]

# %%
x=10000
y=7000

for data in DATA:
    data.setPos(position=[x, y])

data.showPos()
print([data.rx[data.nrx] for data in DATA])
print([data.ry[data.nrx] for data in DATA])
# Out:
# closest point at distance is  12.875004349527433
# Tx distance  1316.7575656406061
# closest point at distance is  12.471615730307223
# Tx distance  1319.9359222733628
# closest point at distance is  14.133277516894339
# Tx distance  1313.5874830849682
# [10012.782179068308, 10012.330304658972, 10013.237229674123]
# [7001.543254763819, 6998.127892646939, 7004.952300871722]

# %%
cols = ["green", "orange", "black", "blue"]
for cmp, xx in zip([cmpx, cmpy, cmpz], ["x", "y", "z"]):
    ax = DATA[0].showSounding(cmp=cmp, color=cols[0], label=f"B{xx} (N={Nvec[0]})")
    for i in range(1, len(DATA)):
        DATA[i].showSounding(cmp=cmp, color=cols[i], label=f"B{xx} (N={Nvec[i]})", ax=ax)

# %%
ax = DATA[1].showSounding(cmp=cmpx, color="blue", label="Bx (N=4)")
DATA[3].showSounding(cmp=cmpx, color="lightblue", label="Bx (N=32)", ax=ax)
ax=DATA[1].showSounding(cmp=cmpy, color="red", label="By (N=4)", ax=ax)
DATA[3].showSounding(cmp=cmpy, color="orange", label="By (N=32)", ax=ax)
ax=DATA[1].showSounding(cmp=cmpz, color="green", label="Bz (N=4)", ax=ax)
DATA[3].showSounding(cmp=cmpz, color="lightgreen", label="Bz (N=32)", ax=ax);
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8324\4276747738.py in <cell line: 2>()
#       1 ax = DATA[1].showSounding(cmp=cmpx, color="blue", label="Bx (N=4)")
# ----> 2 DATA[3].showSounding(cmp=cmpx, color="lightblue", label="Bx (N=32)", ax=ax)
#       3 ax=DATA[1].showSounding(cmp=cmpy, color="red", label="By (N=4)", ax=ax)
#       4 DATA[3].showSounding(cmp=cmpy, color="orange", label="By (N=32)", ax=ax)
#       5 ax=DATA[1].showSounding(cmp=cmpz, color="green", label="Bz (N=4)", ax=ax)
#
# IndexError: list index out of range
