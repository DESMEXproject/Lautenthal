# %%
import numpy as np
from saem import CSEMSurvey, CSEMData

# %%
# Reading Data
txpos = np.genfromtxt("Tx3.pos").T[:, ::-1]
WWU = CSEMData(datafile="../Tx3WWU/tf_merged/*.mat", txPos=txpos)
WWU.setOrigin([589000., 5748000.])

# Nvec = [1, 2, 4, 8, 16, 32, 64]:
Nvec = [2, 4, 8, 32]
DATA = []
for i in Nvec:
    IPHT = CSEMData(datafile=f"../Tx3/tfN{i}/*.mat", txPos=txpos)
    IPHT.setOrigin([589000., 5748000.])
    DATA.append(IPHT)
# Out:
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ['../Tx3WWU/tf_merged\\L00_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L01_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L02_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L03_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L04_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L05_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L06_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L07_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L08_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L09_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L10_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L11_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\L12_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\T00_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\T01_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\T02_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\T03_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\T04_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\T05_UzK_Tx3_ADU08e#019_merged_ltsregress.mat', '../Tx3WWU/tf_merged\\T06_UzK_Tx3_ADU08e#019_merged_ltsregress.mat']
# No frequency in data, try read WWU style
# read ../Tx3WWU/tf_merged\L00_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L01_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L02_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L03_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L04_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L05_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L06_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L07_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L08_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L09_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L10_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L11_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\L12_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\T00_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\T01_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\T02_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\T03_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\T04_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\T05_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# reading ../Tx3WWU/tf_merged\T06_UzK_Tx3_ADU08e#019_merged_ltsregress.mat
# ['../Tx3/tfN2\\20220913_080903_L3011.mat', '../Tx3/tfN2\\20220913_080903_L3019.mat', '../Tx3/tfN2\\20220913_080903_L3021.1.mat', '../Tx3/tfN2\\20220913_080903_L3021.mat', '../Tx3/tfN2\\20220913_080903_L3029.mat', '../Tx3/tfN2\\20220913_080903_L3031.1.mat', '../Tx3/tfN2\\20220913_080903_L3031.2.mat', '../Tx3/tfN2\\20220913_080903_L3031.mat', '../Tx3/tfN2\\20220913_080903_L3039.mat', '../Tx3/tfN2\\20220913_080903_L3041.mat', '../Tx3/tfN2\\20220913_080903_L3049.mat', '../Tx3/tfN2\\20220913_080903_L3051.mat', '../Tx3/tfN2\\20220913_080903_L3059.mat', '../Tx3/tfN2\\20220913_080903_L3061.mat', '../Tx3/tfN2\\20220913_080903_L3069.mat', '../Tx3/tfN2\\20220913_080903_L3071.mat', '../Tx3/tfN2\\20220913_080903_L3079.mat', '../Tx3/tfN2\\20220913_080903_L3081.mat', '../Tx3/tfN2\\20220913_080903_L3091.mat', '../Tx3/tfN2\\20220913_080903_L3101.mat', '../Tx3/tfN2\\20220913_080903_L3111.mat', '../Tx3/tfN2\\20220913_080903_L3121.1.mat', '../Tx3/tfN2\\20220913_080903_L3121.mat', '../Tx3/tfN2\\20220913_080903_L3131.mat']
# No frequency in data, try read WWU style
# read ../Tx3/tfN2\20220913_080903_L3011.mat
# reading ../Tx3/tfN2\20220913_080903_L3019.mat
# reading ../Tx3/tfN2\20220913_080903_L3021.1.mat
# reading ../Tx3/tfN2\20220913_080903_L3021.mat
# reading ../Tx3/tfN2\20220913_080903_L3029.mat
# reading ../Tx3/tfN2\20220913_080903_L3031.1.mat
# reading ../Tx3/tfN2\20220913_080903_L3031.2.mat
# reading ../Tx3/tfN2\20220913_080903_L3031.mat
# reading ../Tx3/tfN2\20220913_080903_L3039.mat
# reading ../Tx3/tfN2\20220913_080903_L3041.mat
# reading ../Tx3/tfN2\20220913_080903_L3049.mat
# reading ../Tx3/tfN2\20220913_080903_L3051.mat
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# reading ../Tx3/tfN8\20220913_080903_L3091.mat
# reading ../Tx3/tfN8\20220913_080903_L3101.mat
# reading ../Tx3/tfN8\20220913_080903_L3111.mat
# reading ../Tx3/tfN8\20220913_080903_L3121.1.mat
# reading ../Tx3/tfN8\20220913_080903_L3121.mat
# reading ../Tx3/tfN8\20220913_080903_L3131.mat
# ['../Tx3/tfN32\\20220913_080903_L3011.mat', '../Tx3/tfN32\\20220913_080903_L3019.mat', '../Tx3/tfN32\\20220913_080903_L3021.mat', '../Tx3/tfN32\\20220913_080903_L3029.mat', '../Tx3/tfN32\\20220913_080903_L3031.1.mat', '../Tx3/tfN32\\20220913_080903_L3039.mat', '../Tx3/tfN32\\20220913_080903_L3041.mat', '../Tx3/tfN32\\20220913_080903_L3049.mat', '../Tx3/tfN32\\20220913_080903_L3051.mat', '../Tx3/tfN32\\20220913_080903_L3059.mat', '../Tx3/tfN32\\20220913_080903_L3061.mat', '../Tx3/tfN32\\20220913_080903_L3069.mat', '../Tx3/tfN32\\20220913_080903_L3071.mat', '../Tx3/tfN32\\20220913_080903_L3079.mat', '../Tx3/tfN32\\20220913_080903_L3081.mat', '../Tx3/tfN32\\20220913_080903_L3091.mat', '../Tx3/tfN32\\20220913_080903_L3101.mat', '../Tx3/tfN32\\20220913_080903_L3111.mat', '../Tx3/tfN32\\20220913_080903_L3121.1.mat', '../Tx3/tfN32\\20220913_080903_L3121.mat', '../Tx3/tfN32\\20220913_080903_L3131.mat']
# No frequency in data, try read WWU style
# read ../Tx3/tfN32\20220913_080903_L3011.mat
# reading ../Tx3/tfN32\20220913_080903_L3019.mat
# reading ../Tx3/tfN32\20220913_080903_L3021.mat
# reading ../Tx3/tfN32\20220913_080903_L3029.mat
# reading ../Tx3/tfN32\20220913_080903_L3031.1.mat
# reading ../Tx3/tfN32\20220913_080903_L3039.mat
# reading ../Tx3/tfN32\20220913_080903_L3041.mat
# reading ../Tx3/tfN32\20220913_080903_L3049.mat
# reading ../Tx3/tfN32\20220913_080903_L3051.mat
# reading ../Tx3/tfN32\20220913_080903_L3059.mat
# reading ../Tx3/tfN32\20220913_080903_L3061.mat
# reading ../Tx3/tfN32\20220913_080903_L3069.mat
# reading ../Tx3/tfN32\20220913_080903_L3071.mat
# reading ../Tx3/tfN32\20220913_080903_L3079.mat
# reading ../Tx3/tfN32\20220913_080903_L3081.mat
# reading ../Tx3/tfN32\20220913_080903_L3091.mat
# reading ../Tx3/tfN32\20220913_080903_L3101.mat
# reading ../Tx3/tfN32\20220913_080903_L3111.mat
# reading ../Tx3/tfN32\20220913_080903_L3121.1.mat
# reading ../Tx3/tfN32\20220913_080903_L3121.mat
# reading ../Tx3/tfN32\20220913_080903_L3131.mat
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
IPHT = DATA[2]
IPHT.showField("line",label='IPHT',radius=30)
WWU.showField("line",label='WWU',radius=30)
# Out:
# (<AxesSubplot:xlabel='x (m)', ylabel='y (m)'>,
#  <matplotlib.colorbar.Colorbar at 0x28b19e57250>)

# %%
# %% Soundings

x=4000
y=0

IPHT.setPos(position=[x,y], show=True)
WWU.setPos(position=[x,y], show=True)

cmpx = [1, 0, 0]
cmpy = [0, 1, 0]
cmpz = [0, 0, 1]

ax=IPHT.showSounding(position=[x,y], cmp=cmpx, color="red", label="Bx IPHT")
IPHT.showSounding(position=[x,y], cmp=cmpy, color="g", label="By IPHT", ax=ax)
IPHT.showSounding(position=[x,y], cmp=cmpz, color="orange", label="Bz IPHT" , ax=ax)

ax=WWU.showSounding(position=[x,y], cmp=cmpx, color="red", label="Bx WWU")
WWU.showSounding(position=[x,y], cmp=cmpy, color="g", label="By WWU", ax=ax)
WWU.showSounding(position=[x,y], cmp=cmpz, color="orange", label="Bz WWU" , ax=ax)

ax=WWU.showSounding(position=[x,y], cmp=cmpx, color="red", label="Bx WWU")
IPHT.showSounding(position=[x,y], cmp=cmpx, color="g", label="Bx IPHT", ax=ax)

ax=WWU.showSounding(position=[x,y], cmp=cmpy, color="red", label="By WWU")
IPHT.showSounding(position=[x,y], cmp=cmpy, color="g", label="By IPHT", ax=ax)

ax=WWU.showSounding(position=[x,y], cmp=cmpz, color="red", label="Bz WWU")
IPHT.showSounding(position=[x,y], cmp=cmpz, color="g", label="Bz IPHT", ax=ax)
# Out:
# closest point at distance is  24.199257554465635
# Tx distance  1211.854500765353
# closest point at distance is  22.54162861974936
# Tx distance  1210.1378745767902
# closest point at distance is  24.199257554465635
# Tx distance  1211.854500765353
# closest point at distance is  24.199257554465635
# Tx distance  1211.854500765353
# closest point at distance is  24.199257554465635
# Tx distance  1211.854500765353
# closest point at distance is  22.54162861974936
# Tx distance  1210.1378745767902
# closest point at distance is  22.54162861974936
# Tx distance  1210.1378745767902
# closest point at distance is  22.54162861974936
# Tx distance  1210.1378745767902
# closest point at distance is  22.54162861974936
# Tx distance  1210.1378745767902
# closest point at distance is  24.199257554465635
# Tx distance  1211.854500765353
# closest point at distance is  22.54162861974936
# Tx distance  1210.1378745767902
# closest point at distance is  24.199257554465635
# Tx distance  1211.854500765353
# closest point at distance is  22.54162861974936
# Tx distance  1210.1378745767902
# closest point at distance is  24.199257554465635
# Tx distance  1211.854500765353
# array([<AxesSubplot:xlabel='|T| (log10 nT/A)', ylabel='f (Hz)'>,
#        <AxesSubplot:xlabel='$\\phi$ (°)'>], dtype=object)

# %%
# %% remove Lines
# IPHT.line[IPHT.line==7] = 0
# IPHT.removeNoneLineData()
# WWU.line[WWU.line==5] = 0
# WWU.removeNoneLineData()
# IPHT.showField("line",label='IPHT')
# WWU.showField("line",label='WWU')

# %%
# %%
IPHTline=1.
WWUline=1.
# freqs=[32,64,128,256,521,1024]
IPHTfreq=[4,6,8,10,12,14]
WWUfreq= [13,11,9,7,5,3]

IPHT.showData(nf=IPHTfreq[5], amphi=False, radius=50.)
WWU.showData(nf=WWUfreq[5], amphi=False, radius=50.)

fig ,ax =IPHT.showData(line=IPHTline,nf=IPHTfreq[0])
WWU.showData(line=WWUline,nf=WWUfreq[0],ax=ax)

fig ,ax =IPHT.showData(line=IPHTline,nf=IPHTfreq[3])
WWU.showData(line=WWUline,nf=WWUfreq[3],ax=ax)

fig ,ax =IPHT.showData(line=IPHTline,nf=IPHTfreq[5])
WWU.showData(line=WWUline,nf=WWUfreq[5],ax=ax)
# Out:
# (<Figure size 720x432 with 6 Axes>,
#  array([[<AxesSubplot:title={'center':'Bx'}, ylabel='$\\Re$(B) (nT/A)'>,
#          <AxesSubplot:title={'center':'By'}>,
#          <AxesSubplot:title={'center':'Bz'}>],
#         [<AxesSubplot:xlabel='x (m)', ylabel='$\\Im$(B) (nT/A)'>,
#          <AxesSubplot:xlabel='x (m)'>, <AxesSubplot:xlabel='x (m)'>]],
#        dtype=object))

# %%
# %% Show Data after Denoising

IPHT.deactivateNoisyData(rErr=0.5)
IPHT.estimateError()  # 5%+1pV/A
IPHT.deactivateNoisyData(rErr=0.5)

WWU.deactivateNoisyData(rErr=0.5)
WWU.estimateError()  # 5%+1pV/A
WWU.deactivateNoisyData(rErr=0.5)

# %%
fig ,ax =IPHT.showLineFreq(line=IPHTline,nf=IPHTfreq[5])
WWU.showLineFreq(line=WWUline,nf=WWUfreq[5],ax=ax)
# Out:
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Program Files\softwares\envs\pgnew\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# (<Figure size 720x432 with 6 Axes>,
#  array([[<AxesSubplot:title={'center':'Bx'}, ylabel='$\\Re$(B) (nT/A)'>,
#          <AxesSubplot:title={'center':'By'}>,
#          <AxesSubplot:title={'center':'Bz'}>],
#         [<AxesSubplot:xlabel='x (m)', ylabel='$\\Im$(B) (nT/A)'>,
#          <AxesSubplot:xlabel='x (m)'>, <AxesSubplot:xlabel='x (m)'>]],
#        dtype=object))

# %%
print(IPHT.f)
print(WWU.f)
print(WWU.f[WWUfreq],IPHT.f[IPHTfreq])
# Out:
# [4.630000e+00 9.260000e+00 1.620000e+01 2.315000e+01 3.200000e+01
#  4.525000e+01 6.400000e+01 9.051000e+01 1.280000e+02 1.810200e+02
#  2.560000e+02 3.620400e+02 5.120000e+02 7.240800e+02 1.024000e+03
#  1.448150e+03 2.048000e+03 2.896310e+03 4.096000e+03 5.792620e+03
#  8.192000e+03 1.158524e+04]
# [2896.31 2048.   1448.15 1024.    724.08  512.    362.04  256.    181.02
#   128.     90.51   64.     46.06   32.41   23.15   13.89    4.63]
# [  32.41   64.    128.    256.    512.   1024.  ] [  32.   64.  128.  256.  512. 1024.]
