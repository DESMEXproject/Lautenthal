# %%
import numpy as np
from saem import CSEMData

# %%
txpos = np.genfromtxt("Tx1.pos").T[:, ::-1]
# Nvec = [1, 2, 4, 8, 16, 32, 64]:
Nvec = [2, 4, 8, 32]
DATA = []
for i in Nvec:
    data = CSEMData(datafile=f"tfN{i}/*.mat", txPos=txpos) # 2 Cycle
    data.setOrigin([580000., 5740000.])
    data.filter(fmin=12, fmax=2000)
    DATA.append(data)
# Out:
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ['tfN2\\20220909_134900_L1011.mat', 'tfN2\\20220909_134900_L1019.mat', 'tfN2\\20220909_134900_L1021.mat', 'tfN2\\20220909_134900_L1029.mat', 'tfN2\\20220909_134900_L1031.mat', 'tfN2\\20220909_134900_L1039.mat', 'tfN2\\20220909_134900_L1041.mat', 'tfN2\\20220909_134900_L1049.mat', 'tfN2\\20220909_134900_L1051.mat', 'tfN2\\20220909_134900_L1059.mat', 'tfN2\\20220909_134900_L1061.mat', 'tfN2\\20220909_134900_L1071.mat', 'tfN2\\20220909_134900_L1081.mat', 'tfN2\\20220909_134900_L1091.mat', 'tfN2\\20220909_134900_L1101.mat', 'tfN2\\20220909_134900_L1111.mat', 'tfN2\\20220909_134900_L1121.mat', 'tfN2\\20220909_134900_L1131.mat', 'tfN2\\20220909_134900_L1141.mat', 'tfN2\\20220909_134900_L1151.mat']
# No frequency in data, try read WWU style
# read tfN2\20220909_134900_L1011.mat
# reading tfN2\20220909_134900_L1019.mat
# reading tfN2\20220909_134900_L1021.mat
# reading tfN2\20220909_134900_L1029.mat
# reading tfN2\20220909_134900_L1031.mat
# reading tfN2\20220909_134900_L1039.mat
# reading tfN2\20220909_134900_L1041.mat
# reading tfN2\20220909_134900_L1049.mat
# reading tfN2\20220909_134900_L1051.mat
# reading tfN2\20220909_134900_L1059.mat
# reading tfN2\20220909_134900_L1061.mat
# reading tfN2\20220909_134900_L1071.mat
# reading tfN2\20220909_134900_L1081.mat
# reading tfN2\20220909_134900_L1091.mat
# reading tfN2\20220909_134900_L1101.mat
# reading tfN2\20220909_134900_L1111.mat
# reading tfN2\20220909_134900_L1121.mat
# reading tfN2\20220909_134900_L1131.mat
# reading tfN2\20220909_134900_L1141.mat
# reading tfN2\20220909_134900_L1151.mat
# ['tfN4\\20220909_134900_L1011.mat', 'tfN4\\20220909_134900_L1019.mat', 'tfN4\\20220909_134900_L1021.mat', 'tfN4\\20220909_134900_L1029.mat', 'tfN4\\20220909_134900_L1031.mat', 'tfN4\\20220909_134900_L1039.mat', 'tfN4\\20220909_134900_L1041.mat', 'tfN4\\20220909_134900_L1049.mat', 'tfN4\\20220909_134900_L1051.mat', 'tfN4\\20220909_134900_L1059.mat', 'tfN4\\20220909_134900_L1061.mat', 'tfN4\\20220909_134900_L1071.mat', 'tfN4\\20220909_134900_L1081.mat', 'tfN4\\20220909_134900_L1091.mat', 'tfN4\\20220909_134900_L1101.mat', 'tfN4\\20220909_134900_L1111.mat', 'tfN4\\20220909_134900_L1121.mat', 'tfN4\\20220909_134900_L1131.mat', 'tfN4\\20220909_134900_L1141.mat', 'tfN4\\20220909_134900_L1151.mat']
# No frequency in data, try read WWU style
# read tfN4\20220909_134900_L1011.mat
# reading tfN4\20220909_134900_L1019.mat
# reading tfN4\20220909_134900_L1021.mat
# reading tfN4\20220909_134900_L1029.mat
# reading tfN4\20220909_134900_L1031.mat
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files
tfN32\\20220909_134900_L1059.mat', 'tfN32\\20220909_134900_L1061.mat', 'tfN32\\20220909_134900_L1071.mat', 'tfN32\\20220909_134900_L1081.mat', 'tfN32\\20220909_134900_L1091.mat', 'tfN32\\20220909_134900_L1101.mat', 'tfN32\\20220909_134900_L1111.mat', 'tfN32\\20220909_134900_L1121.mat', 'tfN32\\20220909_134900_L1131.mat', 'tfN32\\20220909_134900_L1141.mat', 'tfN32\\20220909_134900_L1151.mat']
# No frequency in data, try read WWU style
# read tfN32\20220909_134900_L1011.mat
# reading tfN32\20220909_134900_L1019.mat
# reading tfN32\20220909_134900_L1021.mat
# reading tfN32\20220909_134900_L1029.mat
# reading tfN32\20220909_134900_L1031.mat
# reading tfN32\20220909_134900_L1039.mat
# reading tfN32\20220909_134900_L1041.mat
# reading tfN32\20220909_134900_L1049.mat
# reading tfN32\20220909_134900_L1051.mat
# reading tfN32\20220909_134900_L1059.mat
# reading tfN32\20220909_134900_L1061.mat
# reading tfN32\20220909_134900_L1071.mat
# reading tfN32\20220909_134900_L1081.mat
# reading tfN32\20220909_134900_L1091.mat
# reading tfN32\20220909_134900_L1101.mat
# reading tfN32\20220909_134900_L1111.mat
# reading tfN32\20220909_134900_L1121.mat
# reading tfN32\20220909_134900_L1131.mat
# reading tfN32\20220909_134900_L1141.mat
# reading tfN32\20220909_134900_L1151.mat
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Program Files\software\Anaconda\envs\pg13\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
cmpx = [1, 0, 0]
cmpy = [0, 1, 0]
cmpz = [0, 0, 1]

# %%
x=8000
y=12000

for data in DATA:
    data.setPos(position=[x, y])

data.showPos()
print([data.rx[data.nrx] for data in DATA])
print([data.ry[data.nrx] for data in DATA])
# Out:
# closest point at distance is  9.126007938449604
# Tx distance  1665.6958480117637
# closest point at distance is  10.098049976179588
# Tx distance  1662.8330519411893
# closest point at distance is  13.727464870824608
# Tx distance  1657.1239082055977
# closest point at distance is  9.00918056670826
# Tx distance  1668.565248509061
# [8003.835834305268, 8001.530394305242, 7996.939958709641, 8006.151429683552]
# [12008.28072436899, 12009.981408046558, 12013.382056608796, 12006.58219168149]

# %%
cols = ["green", "orange", "black", "blue"]
for cmp, xx in zip([cmpx, cmpy, cmpz], ["x", "y", "z"]):
    ax = DATA[0].showSounding(cmp=cmp, color="g", label=f"B{xx} (N={Nvec[0]})")
    for i in range(1, len(DATA)):
        DATA[i].showSounding(cmp=cmp, color="orange", label=f"B{xx} (N={Nvec[i]})", ax=ax)

# %%
ax = DATA[2].showSounding(cmp=cmpx, color="blue", label="Bx (N=4)")
DATA[3].showSounding(cmp=cmpx, color="lightblue", label="Bx (N=32)", ax=ax)
ax=DATA[2].showSounding(cmp=cmpy, color="red", label="By (N=4)", ax=ax)
DATA[3].showSounding(cmp=cmpy, color="orange", label="By (N=32)", ax=ax)
ax=DATA[2].showSounding(cmp=cmpz, color="green", label="Bz (N=4)", ax=ax)
DATA[3].showSounding(cmp=cmpz, color="lightgreen", label="Bz (N=32)", ax=ax);
